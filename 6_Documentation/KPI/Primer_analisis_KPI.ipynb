# %% [markdown]
# ## Definimos los indicadores relevantes :
#
# definiendo objetivos como:
#
# - para mejorar la experiencia del cliente, aumentar su fidelidad y adelantarse a la pérdida de clientes
# - ayuda a hacer los cambios correctos y mejorar el negocio.
# - averiguar qué características son más importantes para nuestros clientes
# - saber qué los clientes nos dejan por la competencia
# - saber lo contentos que están mis clientes con mi producto

# %% [markdown]
# <strong>- puntuación de satisfacción del cliente (CSAT)</strong>

# %%
# aplicado a los datos
import pandas as pd

# %%
df_user = pd.read_parquet('/content/drive/MyDrive/Kaarla,/Yelp/user.parquet')

# %%
df_user.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2105597 entries, 0 to 2105596
# Data columns (total 22 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   user_id             object
#  1   name                object
#  2   review_count        int64
#  3   yelping_since       object
#  4   useful              int64
#  5   funny               int64
#  6   cool                int64
#  7   elite               object
#  8   friends             object
#  9   fans                int64
#  10  average_stars       float64
#  11  compliment_hot      int64
#  12  compliment_more     int64
#  13  compliment_profile  int64
#  14  compliment_cute     int64
#  15  compliment_list     int64
#  16  compliment_note     int64
#  17  compliment_plain    int64
#  18  compliment_cool     int64
#  19  compliment_funny    int64
#  20  compliment_writer   int64
#  21  compliment_photos   int64
# dtypes: float64(1), int64(16), object(5)
# memory usage: 353.4+ MB

# %%
df_business =pd.read_pickle(r'/content/drive/MyDrive/Kaarla,/Yelp/business.pkl')
#df_user = pd.read_parquet('/content/drive/MyDrive/Kaarla,/Yelp/user.parquet')
#df_review = pd.read_json('/content/drive/MyDrive/Kaarla,/Yelp/review.json', lines=True)
#df_checkin = pd.read_json('/content/drive/MyDrive/Kaarla,/Yelp/checkin.json', lines=True)
#df_tip = pd.read_json('/content/drive/MyDrive/Kaarla,/Yelp/tip.json', lines=True)

# %%
df_business.iloc[:,list(range(0,14))].info()
#df_business.drop(df_business.loc[:, ''].columns,axis = 1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150346 entries, 0 to 150345
# Data columns (total 14 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   business_id   150346 non-null  object
#  1   name          150346 non-null  object
#  2   address       150346 non-null  object
#  3   city          150346 non-null  object
#  4   state         150343 non-null  object
#  5   postal_code   150346 non-null  object
#  6   latitude      150346 non-null  object
#  7   longitude     150346 non-null  object
#  8   stars         150346 non-null  object
#  9   review_count  150346 non-null  object
#  10  is_open       150346 non-null  object
#  11  attributes    136602 non-null  object
#  12  categories    150243 non-null  object
#  13  hours         127123 non-null  object
# dtypes: object(14)
# memory usage: 17.2+ MB

# %%
#df_business['stars'].astype('float')
df_busi=df_business.iloc[:,list(range(0,14))]
df_busi=df_busi.astype({"stars":'float'})
df_busi #, "Salary":'int'
# Out:
#                    business_id                      name  \
# 0       Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1       mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2       tUFrWirKiKi_TAnsVWINQQ                    Target
# 3       MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4       mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
# ...                        ...                       ...
# 150341  IUQopTMmYQG-qRtBk-8QnA              Binh's Nails
# 150342  c8GjPIOTGVmIemT7j5_SyQ      Wild Birds Unlimited
# 150343  _QAMST-NrQobXduilWEqSw         Claire's Boutique
# 150344  mtGm22y5c2UHNXDFAjaPNw  Cyclery & Fitness Center
# 150345  jV_XOycEzSlTx-65W906pg                   Sic Ink
#
#                                 address           city state postal_code  \
# 0                1616 Chapala St, Ste 2  Santa Barbara   NaN       93101
# 1       87 Grasso Plaza Shopping Center         Affton   NaN       63123
# ...

# %%
#df_business.iloc[:,list(range(0,14))].astype({"stars":'float'}).head(3)[df_business.iloc[:,list(range(0,14))].astype({"stars":'float'}).head(3)['stars']>4]

# %%
#DF_tip=pd.read_json('/content/drive/MyDrive/Kaarla,/Yelp/review.json',lines=True)

# %%
#para categoria hotel
df_busi.explode('categories').dropna(subset=['categories']).reset_index(drop=True)[df_busi.explode('categories').dropna(subset=['categories']).reset_index(drop=True)['categories'].apply(lambda x :  True if 'Hotel' in x.split()  else False)]
# Out:
#                    business_id                      name         address  \
# 59528   UMQrB5IiWGidFjEXSkHOEQ          Queen & Crescent     344 Camp St
# 135983  oHxmQ83FfYbxA_AA72aYgg  La Fusion Restaurant Bar  2650 S 15th St
#
#                 city state postal_code   latitude  longitude  stars  \
# 59528    New Orleans    AZ       70130  29.949805 -90.068964    2.0
# 135983  Philadelphia    FL       19145  39.917253 -75.173161    4.5
#
#        review_count is_open  \
# 59528            85       0
# 135983           28       0
#
#                                                attributes  \
# 59528   {'Ambience': '{'romantic': False, 'intimate': ...
# 135983  {'BusinessAcceptsCreditCards': 'True', 'Alcoho...
#
#                                                categories  \
# 59528   Hotels & Travel, Hotels, Event Planning & Serv...
# 135983  Hotel bar, Nightlife, Restaurants, Asian Fusio...
#
#                                                     hours
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#para categoria restaurant
df_busi.explode('categories').dropna(subset=['categories']).reset_index(drop=True)[df_busi.explode('categories').dropna(subset=['categories']).reset_index(drop=True)['categories'].apply(lambda x :  True if 'Restaurants' in x.split()  else False)].groupby('stars')['stars'].count().plot()
plt.grid()#.agg({'stars':'count'})

# %%
df_busi.explode('categories').dropna(subset=['categories']).reset_index(drop=True)[df_busi.explode('categories').dropna(subset=['categories']).reset_index(drop=True)['categories'].apply(lambda x :  True if 'Restaurants' in x.split()  else False)][df_busi.explode('categories').dropna(subset=['categories']).reset_index(drop=True)[df_busi.explode('categories').dropna(subset=['categories']).reset_index(drop=True)['categories'].apply(lambda x :  True if 'Restaurants' in x.split()  else False)]['stars']>=4].shape
# Out:
# (5880, 14)

# %% [markdown]
# - calculando la puntuacion de satisfaccion del cliente se tiene : (1/2)*100 = 50% en el rubro hotel
# - calculando la puntuacion de satisfaccion del cliente se tiene : (5880/13561)*100 = 43% en el rubro de restaurants
#
# el mayor indice de satisfaccion entre los dos rubros se localiza en hotel

# %% [markdown]
# <strong>- NPS(net promoter score) Puntuación Neta del Promotor</strong>
#
# Net Promoter Score (NPS) es una métrica que las organizaciones utilizan para medir la lealtad del cliente hacia su marca , o servicio.
#
#  % Detractores - % Promotores = NPS
#
#  * determinar la retención y lealtad de los clientes;
#  * determinar la percepción del cliente;
#  * determinar la rotación de clientes; y
#  * Supervisar las mejoras de la organización, productos o servicios

# %%
import os,json
import pandas as pd

# %%
path_to_json = '/content/drive/MyDrive/Kaarla,/Google Maps/metadata-sitios/' # direecion de la carpeta del drive donde se encuentran los archivos de 1-11
lista_dfs=[]
for file_name in [file for file in os.listdir(path_to_json) if file.endswith('.json')]:
  with open(path_to_json + file_name,'r') as json_file:
    #data = json.load(json_file)
    #for line in json_file:
        #line = json.loads(line.strip())
    dd=pd.read_json(json_file,lines=True)
    ff=dd.explode('category').dropna(subset=['category']).reset_index(drop=True)[dd.explode('category').dropna(subset=['category']).reset_index(drop=True)['category'].apply(lambda x :  True if 'Hotel' in x.split()  else False)]
    lista_dfs.append(ff)

# %%
final_df2 = pd.concat(lista_dfs, ignore_index=True)

# %% [markdown]
# <strong>- Índice de Penetración del Mercado (MPI)</strong>
#
# % MPI = Clientes que accedieron al servicio / tamaño total de mercado para este servicio *100
#
# Suponiendo que su mercado tiene 217171  de clientes potenciales, y que la empresa (Econo Lodge) tiene 2491 de clientes en ese mercado, su tasa de cobertura sería de :
#
#  $ PMI={2491 \over 217171}*100= 1.15 % $  es decir  1.15 %
#
#  para Riverwind Casino tiene : 3.99 %
#
#  podemos determinar la popularidad de la empresa.

# %%
(8668/217171)*100
# Out:
# 3.9913248085609956

# %%
final_df2.head(3)
# Out:
#                   name                                            address  \
# 0  Basecamp Guesthouse  Basecamp Guesthouse, 49010 SE Middle Fork Rd, ...
# 1     Sugar River Loft  Sugar River Loft, 929 W Exchange St, Brodhead,...
# 2         Meraki Lodge      Meraki Lodge, 223 Meraki Ln, Manson, WA 98831
#
#                                  gmap_id description   latitude   longitude  \
# 0  0x54907fca2751e187:0x3d6ae31ac18da483        None  47.471332 -121.686928
# 1  0x88062b28cb53ef6d:0x94df72568fddf391        None  42.619862  -89.377890
# 2  0x549b9d4ad8f113d5:0x8258a10cca866a62        None  47.887652 -120.120376
#
#   category  avg_rating  num_of_reviews price hours  MISC state  \
# 0    Hotel         5.0               8  None  None  None  None
# 1    Hotel         4.7               8  None  None  None  None
# 2    Hotel         4.9              15  None  None  None  None
#
#                                     relative_results  \
# ...

# %%
final_df2['num_of_reviews'].sum()
# Out:
# 217171

# %%
final_df2.groupby(['name']).agg({'num_of_reviews':'sum'}).reset_index().sort_values('num_of_reviews',ascending=False) # eleccion al azar una instalacion de hotel ejemplo: Econo Lodge
# Out:
#                                   name  num_of_reviews
# 4126                  Riverwind Casino            8668
# 2280          Horseshoe Council Bluffs            4488
# 4669   Sunland Park Racetrack & Casino            3970
# 4370  Sheraton Fisherman's Wharf Hotel            2545
# 1535                       Econo Lodge            2491
# ...                                ...             ...
# 5425     Veterans Transitional Housing               1
# 923                       Central Stay               1
# 3521                          Oats Bin               1
# 1468           Driftwood Beach Cottage               1
# 2156     Holiday Hills Member Services               1
#
# [5717 rows x 2 columns]

# %% [markdown]
# <strong>- tasa de retencion del cliente </strong>
#
# Se trata de un porcentaje que mide cuántos clientes conserva una empresa al final de un plazo determinado, después de comparar la adquisición de nuevos clientes contra el número de clientes que se perdieron.
#
# ${Clientes\quad al \quad final \quad de \quad un \quad periodo - clientes \quad nuevos \quad adquiridos \quad durante \quad el \quad periodo \over clientes \quad al \quad comienzo \quad del \quad periodo}*100$
#
# Supongamos que al empezar el trimestre con 100 clientes , ingresan 5 nuevos clientes durante ese tiempo y luego pierde 20 ,por lo que terminas el trimestre con 85   :
#
#  $ ={85 - 5 \over 100}*100= 80 % $  es decir 80%
#
# 80% de retenecion de clientes

# %%
df_user = pd.read_parquet('/content/drive/MyDrive/Kaarla,/Yelp/user.parquet')

# %%
df_user
# Out:
#                         user_id         name  review_count  \
# 0        qVc8ODYU5SZjKXVBgXdI7w       Walker           585
# 1        j14WgRoU_-2ZE1aw1dXrJg       Daniel          4333
# 2        2WnXYQFK0hXEoTxPtV2zvg        Steph           665
# 3        SZDeASXq7o05mMNLshsdIA         Gwen           224
# 4        hA5lMy-EnncsH4JoR-hFGQ        Karen            79
# ...                         ...          ...           ...
# 2105592  4QGxxakRZeOlg_qDuxmTeQ     Jennilee            38
# 2105593  tmelBbVBGAzXBVfH2u_R6g        Gerry            19
# 2105594  tpBznnD6uJN3m_pJubj09w        Emily            26
# 2105595  Kst_srPw7GdYydMFYdCtzw  Heatheranne            25
# 2105596  mZl-mH3ZIWLRSd_FfvrXFg      Jessica            30
#
#                yelping_since  useful  funny   cool  \
# 0        2007-01-25 16:47:26    7217   1259   5994
# 1        2009-01-25 04:35:42   43091  13066  27281
# 2        2008-07-25 10:41:00    2086   1010   1003
# ...

# %% [markdown]
# <strong>El Coste de Adquisición del Cliente o CAC : </strong>
#
#  cuánto dinero has utilizado para capturar a nuevos clientes .CAC = (Marketing + Ventas) / Clientes Adquiridos

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
