# %%
import pandas as pd

# %%
df_hotels = pd.read_json("../../2. Datasets/beta/hotelbeds/hotels_us_total_api_1.json")

# %%
df_hotels.head()
# Out:
#    code                                               name  \
# 0  6474                      {'content': 'Hilton Chicago'}
# 1  6478  {'content': 'Four Points by Sheraton Los Angel...
# 2  6480            {'content': 'Sheraton Universal Hotel'}
# 3  6483                 {'content': 'Westin Copley Place'}
# 4  6487  {'content': 'Wyndham Garden New Orleans Airport'}
#
#                                          description countryCode stateCode  \
# 0  {'content': 'Our Hotel's Policies Have Changed...          US        IL
# 1  {'content': 'This charming hotel is just a mil...          US        CA
# 2  {'content': 'This upscale, landmark hotel enjo...          US        CA
# 3  {'content': 'Experience one of Boston's most c...          US        MA
# 4  {'content': 'Wyndham Garden New Orleans Airpor...          US        LA
#
#   destinationCode  zoneCode  \
# 0             ORD         2
# 1             LAX         9
# 2             LAX        21
# 3             BOS         2
# ...
