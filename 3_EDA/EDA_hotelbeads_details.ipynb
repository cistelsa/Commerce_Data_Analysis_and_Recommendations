# %% [markdown]
# ![EDA](../5_Sources/Images/banner_eda.gif)

# %% [markdown]
# <p align="center">
#
# ## **Normalización de Datos - EDA**
#
# </p>
#
# Se evidencia que en varias columnas su contenido está estructurado como diccionario y como formato JSON, la prioridad es analizar estas columnas si son datos relevantes y si es posible desanidarlas en el mismo dataset sin repetir datos se realiza.

# %% [markdown]
# <mark>Parte de este script será reutilizado para agregar a la automatización</mark>

# %% [markdown]
# **`Importante:`** Para que este **EDA** se pueda realizar es necesario tener en cuenta la data analizada de `EDA_hotelbeads.ipynb` a su vez el diccionario de datos realizado en [Excel aquí](https://docs.google.com/spreadsheets/d/1Cb9qUBbyXu-8US3OhfAiyZLHjSJrZstZ/edit?usp=sharing&ouid=105689737903283188966&rtpof=true&sd=true).

# %%
# Usaremos librería Pandas y Json para permitir la lectura de los archivos
import pandas as pd
import json

# %%
# Ruta base donde se encuentran los archivos JSON
path_base = "../2_Datasets/original/hotelbeds/"

# %% [markdown]
# ### Realizamos lectura del dataset

# %%
# Guardamos el dataset en csv para la fácil lectura.
# df_hotels_c = pd.read_csv(path_base + "hotels_details_dataset.csv")

# %% [markdown]
# ### Al Menjar Grandes cantidades de Datos el PC local comienza a limitarse en memoria RAM y en Procesador por lo cual realizamos la toma de una muestra de uno de los lotes de datasets (1 archivo JSON) y procesamos el script pertinente y luego lo corremos en la concatenación de la data, esto reduce los recursos.

# %%
with open(path_base + "hotels_us_details_api_1.json", "r") as archivo:
    data_json = json.load(archivo)

# Accede a la parte de "hotels" si existe en el JSON
if "hotels" in data_json:
    hotels_data = data_json["hotels"]
    # Ahora hotels_data contiene la parte correspondiente a "hotels"
else:
    print("La clave 'hotels' no existe en el JSON.")

df_hotels_d = pd.DataFrame(hotels_data)

# %%
# Revisamos su estructura, tipos de datos
df_hotels_d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 31 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   code               200 non-null    int64
#  1   name               200 non-null    object
#  2   description        200 non-null    object
#  3   country            200 non-null    object
#  4   state              200 non-null    object
#  5   destination        200 non-null    object
#  6   zone               200 non-null    object
#  7   coordinates        200 non-null    object
#  8   category           200 non-null    object
#  9   categoryGroup      200 non-null    object
#  10  chain              162 non-null    object
#  11  accommodationType  200 non-null    object
#  12  boards             197 non-null    object
#  13  segments           193 non-null    object
#  14  address            200 non-null    object
#  15  postalCode         200 non-null    object
#  16  city               200 non-null    object
#  17  email              128 non-null    object
#  18  phones             200 non-null    object
#  19  rooms              200 non-null    object
#  20  facilities         200 non-null    object
#  21  interestPoints     76 non-null     object
#  22  images             200 non-null    object
#  23  wildcards          156 non-null    object
#  24  web                154 non-null    object
#  25  lastUpdate         200 non-null    object
#  26  S2C                166 non-null    object
#  27  ranking            200 non-null    int64
#  28  terminals          81 non-null     object
#  29  issues             7 non-null      object
#  30  license            1 non-null      object
# dtypes: int64(2), object(29)
# memory usage: 48.6+ KB

# %%
df_hotels_d.head()
# Out:
#    code                                               name  \
# 0  6474                      {'content': 'Hilton Chicago'}
# 1  6478  {'content': 'Four Points by Sheraton Los Angel...
# 2  6480            {'content': 'Sheraton Universal Hotel'}
# 3  6483                 {'content': 'Westin Copley Place'}
# 4  6487  {'content': 'Wyndham Garden New Orleans Airport'}
#
#                                          description  \
# 0  {'content': 'Our Hotel's Policies Have Changed...
# 1  {'content': 'This charming hotel is just a mil...
# 2  {'content': 'This upscale, landmark hotel enjo...
# 3  {'content': 'Experience one of Boston's most c...
# 4  {'content': 'Wyndham Garden New Orleans Airpor...
#
#                                              country  \
# 0  {'code': 'US', 'isoCode': 'US', 'description':...
# 1  {'code': 'US', 'isoCode': 'US', 'description':...
# 2  {'code': 'US', 'isoCode': 'US', 'description':...
# 3  {'code': 'US', 'isoCode': 'US', 'description':...
# 4  {'code': 'US', 'isoCode': 'US', 'description':...
#
#                                      state  \
# 0       {'code': 'IL', 'name': 'ILLINOIS'}
# 1     {'code': 'CA', 'name': 'CALIFORNIA'}
# 2     {'code': 'CA', 'name': 'CALIFORNIA'}
# 3  {'code': 'MA', 'name': 'MASSACHUSETTS'}
# 4      {'code': 'LA', 'name': 'LOUISIANA'}
#
#                                          destination  \
# 0  {'code': 'ORD', 'name': {'content': 'Chicago -...
# 1  {'code': 'LAX', 'name': {'content': 'Los Angel...
# 2  {'code': 'LAX', 'name': {'content': 'Los Angel...
# 3  {'code': 'BOS', 'name': {'content': 'Boston - ...
# 4  {'code': 'MSY', 'name': {'content': 'New Orlea...
#
#                                                 zone  \
# 0  {'zoneCode': 2, 'name': 'Downtown', 'descripti...
# 1  {'zoneCode': 9, 'name': 'Los Angeles Internati...
# 2  {'zoneCode': 21, 'name': 'Universal Studios / ...
# 3  {'zoneCode': 2, 'name': 'Back Bay', 'descripti...
# 4  {'zoneCode': 8, 'name': 'Metairie', 'descripti...
#
#                                          coordinates  \
# 0       {'longitude': -87.6244, 'latitude': 41.8725}
# 1  {'longitude': -118.3859708, 'latitude': 33.948...
# 2  {'longitude': -118.35955291287974, 'latitude':...
# 3   {'longitude': -71.077539, 'latitude': 42.348577}
# 4            {'longitude': -90.1227, 'latitude': 30}
#
#                                             category  \
# 0  {'code': '4EST', 'description': {'content': '4...
# 1  {'code': '3EST', 'description': {'content': '3...
# 2  {'code': '3EST', 'description': {'content': '3...
# 3  {'code': 'H4_5', 'description': {'content': '4...
# 4  {'code': '3EST', 'description': {'content': '3...
#
#                                        categoryGroup  ...  \
# 0  {'code': 'GRUPO4', 'description': {'content': ...  ...
# 1  {'code': 'GRUPO3', 'description': {'content': ...  ...
# 2  {'code': 'GRUPO3', 'description': {'content': ...  ...
# 3  {'code': 'GRUPO4', 'description': {'content': ...  ...
# 4  {'code': 'GRUPO3', 'description': {'content': ...  ...
#
#                                       interestPoints  \
# 0  [{'facilityCode': 10, 'facilityGroupCode': 100...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                               images  \
# 0  [{'type': {'code': 'HAB', 'description': {'con...
# 1  [{'type': {'code': 'RES', 'description': {'con...
# 2  [{'type': {'code': 'GEN', 'description': {'con...
# 3  [{'type': {'code': 'GEN', 'description': {'con...
# 4  [{'type': {'code': 'RES', 'description': {'con...
#
#                                            wildcards  \
# 0  [{'roomType': 'ROO.LK', 'roomCode': 'ROO', 'ch...
# 1                                                NaN
# 2                                                NaN
# 3  [{'roomType': 'DBL.ST', 'roomCode': 'DBL', 'ch...
# 4  [{'roomType': 'DBL.KG', 'roomCode': 'DBL', 'ch...
#
#                                                  web  lastUpdate  S2C ranking  \
# 0  www3.hilton.com/en/hotels/illinois/hilton-chic...  2023-07-28   3*      47
# 1      http://www.fourpointslax.com/la-airport-hotel  2023-07-28   3*      82
# 2                                                NaN  2023-07-28   4*     119
# 3            http://www.westincopleyplaceboston.com/  2023-07-28   3*      62
# 4                              www.wyndhamhotels.com  2023-07-28  NaN      55
#
#   terminals issues license
# 0       NaN    NaN     NaN
# 1       NaN    NaN     NaN
# 2       NaN    NaN     NaN
# 3       NaN    NaN     NaN
# 4       NaN    NaN     NaN
#
# [5 rows x 31 columns]

# %% [markdown]
# Preparamos un script para poder determinar que columnas están anidadas en forma de diccionarios, listas o formatos JSON

# %%
# Define una función para determinar el tipo de contenido anidado
def determine_nested_type(cell):
    if isinstance(cell, list) and all(isinstance(item, dict) for item in cell):
        return 'Lista de diccionarios'
    elif isinstance(cell, dict):
        return 'Diccionario'
    elif isinstance(cell, list):
        return 'Lista'
    
    return 'Desconocido'

# Crea un diccionario para almacenar los resultados por columna
results = {}

# Itera a través de las columnas del DataFrame original
for column in df_hotels_d.columns:
    # Inicializa un conjunto para esta columna (conjunto para eliminar duplicados)
    nesteds_type = set()
    
    # Itera a través de las celdas de la columna
    for cell in df_hotels_d[column]:
        # Determina el tipo de contenido anidado
        nested_type = determine_nested_type(cell)
        
        # Si el tipo no es "Desconocido", agrega al conjunto
        if nested_type != 'Desconocido':
            nesteds_type.add(nested_type)
    
    # Almacena el resultado para esta columna en el diccionario de resultados
    results[column] = ', '.join(nesteds_type) if nesteds_type else 'Ninguno'

# Crea un DataFrame a partir del diccionario de resultados
resume_df = pd.DataFrame(list(results.items()), columns=['Columnas', 'Tipos de Contenido Anidado'])

# Muestra el DataFrame resumen
print(resume_df)
# Out:
#              Columnas Tipos de Contenido Anidado
# 0                code                    Ninguno
# 1                name                Diccionario
# 2         description                Diccionario
# 3             country                Diccionario
# 4               state                Diccionario
# 5         destination                Diccionario
# 6                zone                Diccionario
# 7         coordinates                Diccionario
# 8            category                Diccionario
# 9       categoryGroup                Diccionario
# 10              chain                Diccionario
# 11  accommodationType                Diccionario
# 12             boards      Lista de diccionarios
# 13           segments      Lista de diccionarios
# 14            address                Diccionario
# 15         postalCode                    Ninguno
# 16               city                Diccionario
# 17              email                    Ninguno
# 18             phones      Lista de diccionarios
# 19              rooms      Lista de diccionarios
# 20         facilities      Lista de diccionarios
# 21     interestPoints      Lista de diccionarios
# 22             images      Lista de diccionarios
# 23          wildcards      Lista de diccionarios
# 24                web                    Ninguno
# 25         lastUpdate                    Ninguno
# 26                S2C                    Ninguno
# 27            ranking                    Ninguno
# 28          terminals      Lista de diccionarios
# 29             issues      Lista de diccionarios
# 30            license                    Ninguno

# %% [markdown]
# Requerimos la columna **code** que es la que nos identifica en la otra tabla
#
# La **Lista de Diccionarios** hace un llamado a los detalles de los servicios que tiene el Hotel, estos se pueden manejar en su mayoría como una tabla relacionada, para este es necesario un proceso de ETL y normalizado de tablas.
#
# En su mayoría los datos anidados como **Ninguno** son varibles del hotel los cuales ya contiene el otro dataset

# %% [markdown]
# Podemos observar que las columnas que son en forma de **Diccionarios** como: `name`, `description`, `coordinates`, `address`, `city` estas columnas ya se desanidaron en el otro dataset, las restantes son importantes detalles del hotel.

# %% [markdown]
# Eliminamos algunas columnas que ya se encuentran en el dataset de `hotels_dataset.csv`, es el caso de `name, description, coordinates, address, city, email, phones, license, web, S2C, ranking, postalCode, coordinates` en otros casos como el de `license` por tener el 99% de campos vacíos se procede a eliminar la columna ya verificando que los datos no son relevantes.

# %%
# Eliminar columnas con datos null: 'name', 'description', 'coordinates', 'address', 'city', 'email', 'phones', 'license', 'web', 'S2C', 'ranking', 'postalCode'
df_hotels_d = df_hotels_d.drop(columns=['name', 'description', 'coordinates', 'address', 'city', 'email', 'phones', 'license', 'web', 'S2C', 'ranking', 'postalCode'])

# %%
df_hotels_d.head()
# Out:
#    code                                            country  \
# 0  6474  {'code': 'US', 'isoCode': 'US', 'description':...
# 1  6478  {'code': 'US', 'isoCode': 'US', 'description':...
# 2  6480  {'code': 'US', 'isoCode': 'US', 'description':...
# 3  6483  {'code': 'US', 'isoCode': 'US', 'description':...
# 4  6487  {'code': 'US', 'isoCode': 'US', 'description':...
#
#                                      state  \
# 0       {'code': 'IL', 'name': 'ILLINOIS'}
# 1     {'code': 'CA', 'name': 'CALIFORNIA'}
# 2     {'code': 'CA', 'name': 'CALIFORNIA'}
# 3  {'code': 'MA', 'name': 'MASSACHUSETTS'}
# 4      {'code': 'LA', 'name': 'LOUISIANA'}
#
#                                          destination  \
# 0  {'code': 'ORD', 'name': {'content': 'Chicago -...
# 1  {'code': 'LAX', 'name': {'content': 'Los Angel...
# 2  {'code': 'LAX', 'name': {'content': 'Los Angel...
# 3  {'code': 'BOS', 'name': {'content': 'Boston - ...
# 4  {'code': 'MSY', 'name': {'content': 'New Orlea...
#
#                                                 zone  \
# 0  {'zoneCode': 2, 'name': 'Downtown', 'descripti...
# 1  {'zoneCode': 9, 'name': 'Los Angeles Internati...
# 2  {'zoneCode': 21, 'name': 'Universal Studios / ...
# 3  {'zoneCode': 2, 'name': 'Back Bay', 'descripti...
# 4  {'zoneCode': 8, 'name': 'Metairie', 'descripti...
#
#                                             category  \
# 0  {'code': '4EST', 'description': {'content': '4...
# 1  {'code': '3EST', 'description': {'content': '3...
# 2  {'code': '3EST', 'description': {'content': '3...
# 3  {'code': 'H4_5', 'description': {'content': '4...
# 4  {'code': '3EST', 'description': {'content': '3...
#
#                                        categoryGroup  \
# 0  {'code': 'GRUPO4', 'description': {'content': ...
# 1  {'code': 'GRUPO3', 'description': {'content': ...
# 2  {'code': 'GRUPO3', 'description': {'content': ...
# 3  {'code': 'GRUPO4', 'description': {'content': ...
# 4  {'code': 'GRUPO3', 'description': {'content': ...
#
#                                                chain  \
# 0  {'code': 'HILTO', 'description': {'content': '...
# 1  {'code': 'MARIO', 'description': {'content': '...
# 2  {'code': 'MARIO', 'description': {'content': '...
# 3  {'code': 'MARIO', 'description': {'content': '...
# 4  {'code': 'WYNDH', 'description': {'content': '...
#
#                                    accommodationType  \
# 0  {'code': 'H', 'typeMultiDescription': {'conten...
# 1  {'code': 'H', 'typeMultiDescription': {'conten...
# 2  {'code': 'H', 'typeMultiDescription': {'conten...
# 3  {'code': 'H', 'typeMultiDescription': {'conten...
# 4  {'code': 'H', 'typeMultiDescription': {'conten...
#
#                                               boards  \
# 0  [{'code': 'BB', 'description': {'content': 'BE...
# 1  [{'code': 'BB', 'description': {'content': 'BE...
# 2  [{'code': 'BB', 'description': {'content': 'BE...
# 3  [{'code': 'BB', 'description': {'content': 'BE...
# 4  [{'code': 'BB', 'description': {'content': 'BE...
#
#                                             segments  \
# 0  [{'code': 34, 'description': {'content': 'Busi...
# 1  [{'code': 34, 'description': {'content': 'Busi...
# 2  [{'code': 34, 'description': {'content': 'Busi...
# 3  [{'code': 34, 'description': {'content': 'Busi...
# 4  [{'code': 34, 'description': {'content': 'Busi...
#
#                                                rooms  \
# 0  [{'roomCode': 'ROO.RO-1', 'isParentRoom': True...
# 1  [{'roomCode': 'DBL.2Q-NM', 'isParentRoom': Fal...
# 2  [{'roomCode': 'DBL.ST-4', 'isParentRoom': Fals...
# 3  [{'roomCode': 'ROO.RV', 'isParentRoom': False,...
# 4  [{'roomCode': 'TWN.2D', 'isParentRoom': False,...
#
#                                           facilities  \
# 0  [{'facilityCode': 30, 'facilityGroupCode': 10,...
# 1  [{'facilityCode': 30, 'facilityGroupCode': 10,...
# 2  [{'facilityCode': 30, 'facilityGroupCode': 10,...
# 3  [{'facilityCode': 30, 'facilityGroupCode': 10,...
# 4  [{'facilityCode': 30, 'facilityGroupCode': 10,...
#
#                                       interestPoints  \
# 0  [{'facilityCode': 10, 'facilityGroupCode': 100...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                               images  \
# 0  [{'type': {'code': 'HAB', 'description': {'con...
# 1  [{'type': {'code': 'RES', 'description': {'con...
# 2  [{'type': {'code': 'GEN', 'description': {'con...
# 3  [{'type': {'code': 'GEN', 'description': {'con...
# 4  [{'type': {'code': 'RES', 'description': {'con...
#
#                                            wildcards  lastUpdate terminals  \
# 0  [{'roomType': 'ROO.LK', 'roomCode': 'ROO', 'ch...  2023-07-28       NaN
# 1                                                NaN  2023-07-28       NaN
# 2                                                NaN  2023-07-28       NaN
# 3  [{'roomType': 'DBL.ST', 'roomCode': 'DBL', 'ch...  2023-07-28       NaN
# 4  [{'roomType': 'DBL.KG', 'roomCode': 'DBL', 'ch...  2023-07-28       NaN
#
#   issues
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
