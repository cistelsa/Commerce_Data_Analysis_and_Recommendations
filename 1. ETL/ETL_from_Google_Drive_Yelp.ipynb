# %% [markdown]
# ![Banner ETL](../5.%20Sources/Images/banner_etl.gif)

# %% [markdown]
# ## Descarga de la data estática de Yelp directamente desde Google Drive al datalake

# %%
pip install gdown # Instalación de paquetes de gdown que no vienen por defecto
# Out:
# StatementMeta(, d121249c-bec5-417c-bc4c-20619272de4d, 3, Finished, Available)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import gdown
# Out:
# StatementMeta(, d121249c-bec5-417c-bc4c-20619272de4d, 4, Finished, Available)

# %%
# Función para extraer el dataset y guardar una copia
def extract_datsets(id_google, file_name):
    # Enlace directo al archivo en Google Drive (asegúrate de que sea el ID correcto del enlace de descarga)
    dataset_g_drive = f"https://drive.google.com/uc?id={id_google}"
    response = gdown.download(dataset_g_drive, output=f"/lakehouse/default/Files/data/original/Yelp/{file_name}", quiet=True)
# Out:
# StatementMeta(, d121249c-bec5-417c-bc4c-20619272de4d, 7, Finished, Available)

# %%
# Descarga dataset "user.parquet"
id_google = "1TT4ARRIV6i2fO1b5yb0aSUkjhxMb9u6g"
file_name = "user.parquet"

extract_datsets(id_google, file_name)
# Out:
# StatementMeta(, e3a92174-6f3d-4c0b-931a-2adadfce01f2, 7, Finished, Available)

# %%
# Descarga dataset "checkin.json"
id_google = "1e27q1-_ecuzGjFC1gtRXoYcZqv1NBie1"
file_name = "checkin.json"

extract_datsets(id_google, file_name)
# Out:
# StatementMeta(, 127c763c-0b94-403a-80bb-cc5e3c18e2b0, 6, Finished, Available)

# %%
# Descarga dataset "review.json"
id_google = "1mwNNdOMSNty6WumYdH9FJNJZJYQ6oD1c"
file_name = "review.json"

extract_datsets(id_google, file_name)
# Out:
# StatementMeta(, 127c763c-0b94-403a-80bb-cc5e3c18e2b0, 7, Submitted, Running)

# %%
# Descarga dataset "tip.json"
id_google = "16I4fnJgOISvOK_ePN-BQ8dQbxtep9_8m"
file_name = "tip.json"

extract_datsets(id_google, file_name)
# Out:
# StatementMeta(, d121249c-bec5-417c-bc4c-20619272de4d, 8, Finished, Available)
